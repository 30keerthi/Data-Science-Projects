# %% [markdown]
# ---
#
#
# <h1> <center>CREDIT CARD FRAUD DETECTION </H1>
#
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# # INTRODUCTION
#
# ---

# %% [markdown]
# *   **Project Goal:** To develop a robust system that identifies and prevents fraudulent transactions in real-time.
# *   **Objective:** Train a machine learning model to classify Credit Card as Fraudulent Credit cards or Real credit card.
# *   **Benefits:**  Protects customers from unauthorized transactions, fostering loyalty and positive relationships.
# *   **Methods:** Utilize machine learning techniques for training and classification.

# %% [markdown]
# ---
#
#
# #APPROACH
#
# ---

# %% [markdown]
# 1. Import all the libraries
# 2. Load and Audit the data
# 3. Data preparation and Data Transformation
#       1. Missing values: impute all missing values using Mean,Median and Mode
#       2. Inconistent values: Replace all inconsistence with consistent values
#       3. Outliers: Transform or let algorithm deal
# 4. Data Visualization
# 5. Data Analysis
#       1. Uni-Variant Analysis
#       2. Bi-Varient Analysis
#       3. Multi-Varient Analysis
#           1. Classification Problem
#           2. Apply Machine Learing Models
#           3. Compare and bring out the best Model

# %% [markdown]
# ---
#
#
# # IMPORTING LIBRARIES
# ---

# %%
import os
os.environ['KAGGLE_USERNAME'] = "keerthiks30" # username from the json file
os.environ['KAGGLE_KEY'] = "00b7ff7f9517a3a4c10d840d244af66e" # key from the json file
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# ...
#  92% 61.0M/66.0M [00:00<00:00, 166MB/s]
# 100% 66.0M/66.0M [00:00<00:00, 119MB/s]

# %%
# !unzip '/content/creditcardfraud.zip'
# Out:
# Archive:  /content/creditcardfraud.zip
#   inflating: creditcard.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
import xgboost as xgb
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ---
#
#
# # READING AND AUDITING DATASET
# ---

# %%
df = pd.read_csv("/content/creditcard.csv")

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print("No of Rows:",df.shape[0])
print("No of Columns:",df.shape[1])
# Out:
# No of Rows: 284807
# No of Columns: 31

# %%
#Summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# > **INFERENCE:**
#
# All the columns are numerical.

# %%
#Statistical Description for Numerical Variable
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# > **INFERENCE:**
#
# There is no missing values.

# %%
#Checking for duplicate values
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool

# %% [markdown]
# > **INFERENCE:**
#
# There is no duplicate values.

# %% [markdown]
# ---
#
#
# # DATA VISUALISATION
#
# ---

# %%
#Visualizing Correlation of the data
plt.figure(figsize=(16,7))
sns.heatmap(df.corr(),annot=True,fmt='0.1f',cmap='PuBuGn')
# Out:
# <Axes: >

# %%
#Distribution of Target variable
plt.title('Target Class Distribution')
df['Class'].value_counts().plot(kind='pie',autopct='%0.2f%%',colors=['lightblue', 'teal'])
# Out:
# <Axes: title={'center': 'Target Class Distribution'}, ylabel='Class'>

# %% [markdown]
# > **INFERENCE:**
#
# We can find that, The data is highly imbalanced.
#
#
#
# *   99.69% belongs to Non-Fraud class
# *   0.31% belongs to Fraudulent Credit cards

# %%
#Disttribution of Amount
plt.figure(figsize=(10, 6))
sns.distplot(df['Amount'],color='teal')
plt.xlabel('Amount')
plt.ylabel('Density')
plt.title('Distribution of Amount')
plt.show()
# Out:
# <ipython-input-17-3283a12bfc26>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Amount'],color='teal')

# %%
#Distrivution of Numerical Variable
df.hist(figsize=(20,20),color='teal')
plt.show()

# %%
# Distribution of our dataset in Time
plt.figure(figsize=(6,4))
sns.kdeplot(df['Time'],color='teal')
plt.show()

# %% [markdown]
# ---
#
#
# # DATA TRANSFORMATION
#
# ---

# %% [markdown]
# ## SPLIT THE TRAIN AND TEST DATA
#
# ---

# %%
x=df.drop(['Class'],axis=1)
y=df['Class']

# %%
print(x.shape)
print(y.shape)
# Out:
# (284807, 30)
# (284807,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (227845, 30)
# (227845,)
# (56962, 30)
# (56962,)

# %% [markdown]
# ## TREATING THE IMBALANCED DATA
#
# ---

# %%
from imblearn.over_sampling import SMOTE
x = x.loc[:,~x.columns.duplicated()]
sm = SMOTE(random_state=42)
x_bal, y_bal= sm.fit_resample(x, y,)

# %%
#Visualising the imbalanced data
y_bal.value_counts().plot(kind='bar', title='Class', color=['lightblue', 'teal'],figsize=(6,5))
# Out:
# <Axes: title={'center': 'Class'}>

# %% [markdown]
# ## STANDARDIZATION
#
# ---

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ---
#
#
# # BUIDLING MODEL
#
# ---

# %% [markdown]
# ## LOGISTIC REGRESSION
#
# ---

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)

lr_preds_train = lr.predict(x_train)
lr_preds_test = lr.predict(x_test)

print('Train accuracy score of the model is: ', round(accuracy_score(y_train, lr_preds_train),2))
print('Test accuracy score of the model is: ', round(accuracy_score(y_test, lr_preds_test),2))
# Out:
# Train accuracy score of the model is:  1.0
# Test accuracy score of the model is:  1.0

# %% [markdown]
# ##   RANDOM FOREST
#
#
# ---

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train, y_train)

rf_preds_train = rf.predict(x_train)
rf_preds_test = rf.predict(x_test)

print('Train accuracy score of the model is: ', round(accuracy_score(y_train, rf_preds_train),2))
print('Test accuracy score of the model is: ', round(accuracy_score(y_test, rf_preds_test),2))
# Out:
# Train accuracy score of the model is:  1.0
# Test accuracy score of the model is:  1.0

# %% [markdown]
# ## XG BOOST
#
# ---

# %%
xgb = xgb.XGBClassifier()
xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xgb_preds_train = xgb.predict(x_train)
xgb_preds_test = xgb.predict(x_test)

print('Train accuracy score of the model is: ', round(accuracy_score(y_train, xgb_preds_train),2))
print('Test accuracy score of the model is: ', round(accuracy_score(y_test, xgb_preds_test),2))
# Out:
# Train accuracy score of the model is:  1.0
# Test accuracy score of the model is:  1.0

# %% [markdown]
# ## NAIVE BAYES
#
# ---

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train, y_train)

gnb_preds_train = gnb.predict(x_train)
gnb_preds_test = gnb.predict(x_test)

print('Train accuracy score of the model is: ', round(accuracy_score(y_train, rf_preds_train),2))
print('Test accuracy score of the model is: ', round(accuracy_score(y_test, rf_preds_test),2))
# Out:
# Train accuracy score of the model is:  1.0
# Test accuracy score of the model is:  1.0

# %% [markdown]
# ## K-NEAREST NEIGHBOURS
#
# ---

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)

knn_preds_train = knn.predict(x_train)
knn_preds_test = knn.predict(x_test)

print('Train accuracy score of the model is: ', round(accuracy_score(y_train, knn_preds_train),2))
print('Test accuracy score of the model is: ', round(accuracy_score(y_test, knn_preds_test),2))
# Out:
# Train accuracy score of the model is:  1.0
# Test accuracy score of the model is:  1.0

# %% [markdown]
# ---
#
#
# # CONCLUSION
#
# ---

# %% [markdown]
# *   Successfully developed an Credit Card Fraud detector using Python and machine learning techniques.
# *   Machine learning models can be continuously trained and updated to adapt to evolving fraud tactics.
#
# *    Demonstrated the practical application of machine learning in enhancing cybersecurity.
